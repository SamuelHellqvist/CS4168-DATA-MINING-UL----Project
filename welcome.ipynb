# %% [markdown]
# Project in the course Data Mining. Univerity of Limerick, spring term 2026
#
# Made by:
# Cullen
# Jan
# Peteri
# Samuel

# %%
print("welcome to the repository")
# Out:
# welcome to the repository

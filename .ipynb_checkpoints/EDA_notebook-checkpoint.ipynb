# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 1. Loading Data & Overview

# %%
import pandas as pd

# %%
df = pd.read_csv('tracks2026.csv')
df
# Out:
#                     track_id  popularity  duration_ms  explicit  danceability  \
# 0     5xmO5SbFOiVrRGrMQhL4Jk        44.0       203337     False         0.608
# 1     5cF0dROlMOK5uNZtivgu50        83.0       208786     False         0.775
# 2     4OQ9XGe11ckizN2EBnNED2        49.0       262373     False         0.797
# 3     6Grw9OtoslF9JrDJ6pgsQG         0.0       191733     False         0.582
# 4     3fGpNiwYr981n72YY4DZvB        41.0       283706     False         0.705
# ...                      ...         ...          ...       ...           ...
# 1995  4pcpqfSn8tfm6vQMMZPjpM        25.0       266133     False         0.794
# 1996  1WM80A5a4xDtlndjqjZQIv        52.0       223236     False         0.667
# 1997  4drUfuJw6c9M5cXA8p7upO         0.0       162009     False         0.541
# 1998  6ULjJomtdRstnT9BPMAf9d        58.0       120000     False         0.853
# 1999  46qnV2b4tq0QqJwIoZwMyJ        25.0       244026     False         0.746
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.553   10    -3.493     1       0.0271        0.3930
# 1      0.613    3    -4.586     0       0.0542        0.1090
# 2      0.612    2    -9.043     0       0.0313        0.2710
# 3      0.829    9    -3.517     1       0.1930        0.0522
# 4      0.713    4    -6.676     0       0.0437        0.2600
# ...      ...  ...       ...   ...          ...           ...
# 1995   0.919    9    -3.037     1       0.0619        0.1540
# 1996   0.629    0    -8.493     1       0.0324        0.1750
# 1997   0.753    0    -6.512     1       0.0511        0.0677
# 1998   0.511    7    -6.451     0       0.4220        0.1880
# 1999   0.570    7   -10.599     1       0.0389        0.6660
#
#       instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0             0.000000    0.1530    0.541  143.993               3       r-n-b
# 1             0.000023    0.1340    0.797  100.066               4         pop
# 2             0.000011    0.3140    0.919  118.162               4   synth-pop
# 3             0.000000    0.2640    0.716   90.959               4   indie-pop
# 4             0.000016    0.0499    0.498  129.899               4   synth-pop
# ...                ...       ...      ...      ...             ...         ...
# 1995          0.000000    0.2480    0.963  133.550               4   synth-pop
# 1996          0.116000    0.0915    0.455  115.002               4   synth-pop
# 1997          0.000000    0.1080    0.572  149.743               4   indie-pop
# 1998          0.000000    0.2230    0.795   90.171               4     hip-hop
# 1999          0.000005    0.3200    0.657  109.929               4   synth-pop
#
# [2000 rows x 17 columns]

# %% [markdown]
# Each row is a track. There are 17 different columns. Three columns (track_id, explicit and track_genre) contain something else than numbers, rest contain numbers. Track id is the id of the track, so it can be used to identify the track.

# %% [markdown]
# ## 2. Categorical Variables

# %%
df['explicit'].value_counts(dropna=False)
# Out:
# explicit
# False    1777
# True      223
# Name: count, dtype: int64

# %%
df['track_genre'].value_counts(dropna=False)
# Out:
# track_genre
# pop          500
# indie-pop    500
# synth-pop    400
# r-n-b        300
# hip-hop      300
# Name: count, dtype: int64

# %% [markdown]
# Explicit and track_genre -columns can be left as they are as they do not contain any missing values. Explicit-column is unbalanced which needs to be considered later on in the modelling part.

# %%
df['mode'].value_counts(dropna=False)
# Out:
# mode
# 1    1275
# 0     725
# Name: count, dtype: int64

# %%
df['key'].value_counts(dropna=False)
# Out:
# key
# 0     243
# 1     193
# 7     192
# 9     187
# 5     184
# 2     173
# 8     157
# 11    154
# 6     152
# 4     147
# 10    143
# 3      75
# Name: count, dtype: int64

# %%
df['time_signature'].value_counts(dropna=False)
# Out:
# time_signature
# 4    1838
# 3     115
# 1      27
# 5      20
# Name: count, dtype: int64

# %% [markdown]
# Column 'mode' seems to be categorical, containing only values 0 or 1. Column 'key' is Pitch class map of integers 0-11 and also categorical. Column 'time_signature' is also categorical and is heavily focused in value of 4 (almost all the data).

# %% [markdown]
# ## 3. Numeric Variables
#
# In the following, the numeric columns will be examined for distributions, outliers, and missing values.

# %%
df.describe()
# Out:
#         popularity    duration_ms  danceability       energy          key  \
# count  1960.000000    2000.000000   1960.000000  1960.000000  2000.000000
# mean     39.805102  217806.433000      0.635897     0.632489     5.295500
# std      29.245904   56804.759189      0.138298     0.189087     3.567148
# min       0.000000   60000.000000      0.185000     0.090900     0.000000
# 25%       1.750000  181210.000000      0.548000     0.507750     2.000000
# 50%      45.000000  211346.000000      0.646000     0.644000     5.000000
# 75%      65.000000  246069.750000      0.738000     0.780000     8.000000
# max     100.000000  561133.000000      0.953000     0.996000    11.000000
#
#             loudness         mode  speechiness  acousticness  \
# count    1961.000000  2000.000000  2000.000000   2000.000000
# mean      400.575884     0.637500     0.078466      0.297378
# std     18065.717039     0.480842     0.076223      0.279793
# min       -21.089000     0.000000     0.022100      0.000007
# 25%        -8.988000     0.000000     0.034475      0.052475
# 50%        -6.924000     1.000000     0.047500      0.195500
# 75%        -5.390000     1.000000     0.084950      0.490250
# max    800000.000000     1.000000     0.515000      0.990000
#
#        instrumentalness     liveness      valence        tempo  time_signature
# count       2000.000000  2000.000000  2000.000000  1960.000000     2000.000000
# mean           0.030269     0.180715     0.539963   120.040092        3.912000
# std            0.119946     0.149938     0.236062    28.520528        0.425848
# min            0.000000     0.009860     0.035900    51.037000        1.000000
# 25%            0.000000     0.093775     0.353000    96.956000        4.000000
# 50%            0.000007     0.121000     0.536000   118.711500        4.000000
# 75%            0.000638     0.221250     0.730000   139.746250        4.000000
# max            0.962000     0.986000     0.990000   205.895000        5.000000

# %% [markdown]
# Columns 'popularity', 'danceability', 'energy', 'loudness' and 'tempo' have missing values. They all seem to be in the same rows.

# %%
df_nans = df[df["popularity"].isnull() | df["danceability"].isnull() | df["energy"].isnull() | df["loudness"].isnull() | df["tempo"].isnull() ]
df_nans
# Out:
#                     track_id  popularity  duration_ms  explicit  danceability  \
# 29    1n5gnI3Wue9WBpYFOIQNh1         NaN       341386     False           NaN
# 56    0hcvwkxhxlIRdeLb1dWJBT         NaN       245187     False           NaN
# 65    1PYCOTJ2g3WJkFsgLlzIEW         NaN       185133      True           NaN
# 99    08HJeHs0U9iSbDWX0sWIem         NaN       169371     False           NaN
# 128   08EzywoYzT4unsQXslM9RA         NaN       268560     False           NaN
# 254   6IdUSDkIkBP7ZmTIZrZiVV         NaN       135053      True           NaN
# 275   52gGYiO7QQtQMpvF8OBHDV         NaN       213573     False           NaN
# 353   1QZRCi2Z1DQQaR6bGAzhtN         NaN       224444     False           NaN
# 374   2qPNdVlqZl1cYqsNc3MXnA         NaN       134351     False           NaN
# 450   7hUxzSsK2OHjeKWkzeArIU         NaN       248006     False           NaN
# 572   18AJRdgUoO9EYn11N7xzaT         NaN       209160     False           NaN
# 584   4BppmhMgZbObWXLwFRxOjC         NaN       219517     False           NaN
# 628   0WtM2NBVQNNJLh6scP13H8         NaN       239317     False           NaN
# 674   4bt0XG1MoZ1fkZ095X6WHC         NaN       202718     False           NaN
# 746   0JBnAsReYppHqCZJbqy5H8         NaN       249662     False           NaN
# 792   4R8BdwRidxAWaYyFNU00P1         NaN       226216     False           NaN
# 905   2nGFzvICaeEWjIrBrL2RAx         NaN       215360     False           NaN
# 907   0cVrLxeQjiAcftuGzp32qY         NaN       378020     False           NaN
# 938   709mEkXJxSopnAmOnRJGRr         NaN       171880      True           NaN
# 944   2JEvkGpibMvl7nAymPedyW         NaN       256000     False           NaN
# 964   1pwx37YPdId6FbA7pEpfRM         NaN       328680     False           NaN
# 1078  2IVsRhKrx8hlQBOWy4qebo         NaN       216880     False           NaN
# 1080  4UF7pAsGCfepAjidu2sAXl         NaN       184315     False           NaN
# 1083  1v1oIWf2Xgh54kIWuKsDf6         NaN       248826     False           NaN
# 1118  1gMnyo0OUAL6HDJ39lyVwU         NaN       170813     False           NaN
# 1179  32UKoTb2CIuM9YeqYnWcvk         NaN       214626     False           NaN
# 1273  5SQIEHNedYoJqOAB9x2DDF         NaN       158533     False           NaN
# 1289  39ujbBjTwwqUFySaCYDMMT         NaN       178604     False           NaN
# 1290  769Fq73HiVK9qfOQKKvpLB         NaN       217666     False           NaN
# 1292  3nEzYBBijcwanwIopweEgv         NaN       170375     False           NaN
# 1323  7d7whQmni6ZvmfkWE5XEAX         NaN       135053      True           NaN
# 1333  15og0pCEcTFWEXOFKdcJlU         NaN       188066     False           NaN
# 1609  1OxYob8D3iKQOitl3TIPZ5         NaN       193143     False           NaN
# 1646  2UzTljfQR9QLGgpVWBunko         NaN       255680     False           NaN
# 1664  3nwOoBMpsg7WDoOhjcnFsm         NaN       239806     False           NaN
# 1731  77eT8QCTlZg8Mje7P9U0NH         NaN       197442     False           NaN
# 1852  5m62bM6EN1ysBb3nnedLBR         NaN       277500     False           NaN
# 1860  1n1b2lwdRdWF5RAaA0vewk         NaN       290493     False           NaN
# 1922  3TAxLyCtWcLqPBVE1rtj6k         NaN       261866     False           NaN
# 1981  5Gk36wgJ5QwSCS2WFqlpRf         NaN       227478      True           NaN
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 29       NaN   11       NaN     1       0.3310      0.237000
# 56       NaN    5       NaN     0       0.0372      0.102000
# 65       NaN    8       NaN     1       0.0502      0.512000
# 99       NaN    9       NaN     1       0.0999      0.739000
# 128      NaN    5       NaN     1       0.0262      0.257000
# 254      NaN   11       NaN     1       0.0762      0.001610
# 275      NaN    9       NaN     1       0.0299      0.513000
# 353      NaN   11       NaN     0       0.1170      0.256000
# 374      NaN    7       NaN     1       0.2090      0.043300
# 450      NaN    2       NaN     1       0.0330      0.430000
# 572      NaN    5       NaN     1       0.0315      0.070300
# 584      NaN    8       NaN     1       0.0315      0.082400
# 628      NaN   11       NaN     1       0.0381      0.382000
# 674      NaN    0       NaN     1       0.0567      0.163000
# 746      NaN   10       NaN     0       0.0812      0.026300
# 792      NaN    9       NaN     0       0.1240      0.221000
# 905      NaN    9       NaN     1       0.0362      0.167000
# 907      NaN    0       NaN     1       0.0275      0.203000
# 938      NaN    4       NaN     0       0.1710      0.034000
# 944      NaN    9       NaN     0       0.0422      0.006230
# 964      NaN    0       NaN     1       0.0414      0.000030
# 1078     NaN    0       NaN     1       0.0256      0.245000
# 1080     NaN    7       NaN     0       0.1260      0.000993
# 1083     NaN   11       NaN     1       0.0372      0.629000
# 1118     NaN    1       NaN     0       0.0413      0.010600
# 1179     NaN    8       NaN     0       0.1730      0.167000
# 1273     NaN    8       NaN     1       0.0444      0.825000
# 1289     NaN    1  800000.0     0       0.0851      0.485000
# 1290     NaN    0       NaN     1       0.0635      0.226000
# 1292     NaN    2       NaN     1       0.0291      0.836000
# 1323     NaN   11       NaN     1       0.0762      0.001610
# 1333     NaN    8       NaN     1       0.0644      0.087500
# 1609     NaN    8       NaN     1       0.3490      0.739000
# 1646     NaN    5       NaN     1       0.0525      0.217000
# 1664     NaN    0       NaN     0       0.0569      0.014200
# 1731     NaN    2       NaN     1       0.0437      0.055800
# 1852     NaN    6       NaN     1       0.1110      0.543000
# 1860     NaN    1       NaN     0       0.2000      0.163000
# 1922     NaN    0       NaN     1       0.0297      0.414000
# 1981     NaN   11       NaN     0       0.2600      0.063100
#
#       instrumentalness  liveness  valence  tempo  time_signature track_genre
# 29            0.000000    0.0791   0.6760    NaN               4         pop
# 56            0.000000    0.2290   0.6020    NaN               4   synth-pop
# 65            0.000000    0.0638   0.9660    NaN               4       r-n-b
# 99            0.000000    0.0919   0.3160    NaN               4       r-n-b
# 128           0.000013    0.1780   0.8700    NaN               4   synth-pop
# 254           0.098500    0.1060   0.4050    NaN               4     hip-hop
# 275           0.000002    0.0880   0.8400    NaN               4       r-n-b
# 353           0.000000    0.6140   0.6620    NaN               4     hip-hop
# 374           0.000029    0.0752   0.7560    NaN               4     hip-hop
# 450           0.000000    0.1510   0.2420    NaN               4         pop
# 572           0.000066    0.0829   0.3480    NaN               4   synth-pop
# 584           0.000002    0.1050   0.3480    NaN               4   indie-pop
# 628           0.000669    0.1140   0.8020    NaN               4         pop
# 674           0.000004    0.1090   0.5940    NaN               4         pop
# 746           0.000000    0.2600   0.5940    NaN               4         pop
# 792           0.550000    0.0964   0.2580    NaN               3   indie-pop
# 905           0.000001    0.1330   0.5420    NaN               4       r-n-b
# 907           0.000366    0.0739   0.5770    NaN               4         pop
# 938           0.000000    0.3150   0.5410    NaN               4         pop
# 944           0.000369    0.1410   0.0678    NaN               4   synth-pop
# 964           0.104000    0.0900   0.2490    NaN               3   synth-pop
# 1078          0.000024    0.2500   0.4880    NaN               3   indie-pop
# 1080          0.000241    0.1410   0.7310    NaN               4   indie-pop
# 1083          0.000078    0.1040   0.1230    NaN               4         pop
# 1118          0.000000    0.1320   0.2900    NaN               4         pop
# 1179          0.000002    0.1000   0.4220    NaN               4   synth-pop
# 1273          0.000005    0.1440   0.4770    NaN               4       r-n-b
# 1289          0.000000    0.3180   0.4900    NaN               4         pop
# 1290          0.000000    0.3770   0.5360    NaN               4       r-n-b
# 1292          0.000000    0.2170   0.3730    NaN               4   indie-pop
# 1323          0.098500    0.1060   0.4050    NaN               4     hip-hop
# 1333          0.000000    0.1470   0.7620    NaN               4   indie-pop
# 1609          0.143000    0.1060   0.2050    NaN               4         pop
# 1646          0.017900    0.0835   0.7710    NaN               4     hip-hop
# 1664          0.010200    0.1090   0.6950    NaN               4   synth-pop
# 1731          0.000000    0.3510   0.8480    NaN               4         pop
# 1852          0.000000    0.0755   0.8390    NaN               4     hip-hop
# 1860          0.000085    0.0662   0.6640    NaN               4     hip-hop
# 1922          0.099600    0.0713   0.8440    NaN               4       r-n-b
# 1981          0.000000    0.1850   0.8350    NaN               4     hip-hop

# %% [markdown]
# Let us look the numerical values in two parts, first columns 'popularity','duration_ms', 'danceability', 'energy', 'loudness', 'speechiness'.

# %%
import matplotlib.pyplot as plt
df[['popularity','duration_ms', 'danceability', 'energy', 'loudness', 'speechiness']].boxplot(rot = 45)
plt.show()

# %%
import matplotlib.pyplot as plt
df[['popularity','duration_ms']].hist()
plt.show()
df[['danceability', 'energy']].hist()
plt.show()
df[['loudness', 'speechiness']].hist()
plt.show()

# %% [markdown]
# As can be seen in the boxplot, duration, danceability, energy, loudness and speechines all have outliers. Also the scale of duration is far more dominant than other features. All of these columns are at least a bit skewed, which can be seen in the histograms.

# %%
df[df['loudness']> 0]
# Out:
#                     track_id  popularity  duration_ms  explicit  danceability  \
# 1289  39ujbBjTwwqUFySaCYDMMT         NaN       178604     False           NaN
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 1289     NaN    1  800000.0     0       0.0851         0.485
#
#       instrumentalness  liveness  valence  tempo  time_signature track_genre
# 1289               0.0     0.318     0.49    NaN               4         pop

# %%
import matplotlib.pyplot as plt
loudness = df[df['loudness']<=0]['loudness'].to_numpy()
plt.hist(loudness)
plt.title('Histogram of loudness without outlier')
plt.xlabel('Loudness')
plt.ylabel('count')
plt.grid()
plt.show()

# %%
plt.boxplot(loudness)
plt.title('Boxplot of loudness without obvious outlier')
plt.xlabel('Loudness')
plt.ylabel('Value')
plt.grid()
plt.show()

# %% [markdown]
# There seems to be one incorrect datapoint in the loudness column (record 1289), as other values are negative and the value of the record in question is 800000.

# %% [markdown]
# Suggestion for data preparation of the columns 'popularity','duration_ms', 'danceability', 'energy', 'loudness', 'speechiness':
# Drop the record of 1289.
# For column popularity, use standard scaler and log transformation.
# For columns rest columns, use robust scaler and log transformation.

# %% [markdown]
# Let us next explore columns 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'.

# %%
df[['acousticness', 'instrumentalness']].hist()
plt.show()
df[['liveness', 'valence', 'tempo']].hist()
plt.show()

# %%
df[['acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']].boxplot()
plt.show()

# %% [markdown]
# As can be seen, instrumentalness, liveness and tempo have outliers. All of these columns are at least a bit skewed but acousticness, instrumentalness and liveness the most.

# %% [markdown]
# Suggestion for data preparation:
# For acousticness and valence, use standard scaler and log transformation.
# For rest of the columns, use robust scaler and log transformation.

# %% [markdown]
# ## 4. Correlation Analysis

# %%
df[['popularity','duration_ms', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']].corr()
# Out:
#                   popularity  duration_ms  danceability    energy  loudness  \
# popularity          1.000000     0.026282     -0.023186 -0.017372 -0.010803
# duration_ms         0.026282     1.000000     -0.209369  0.043982 -0.015551
# danceability       -0.023186    -0.209369      1.000000  0.112448  0.151525
# energy             -0.017372     0.043982      0.112448  1.000000  0.632503
# loudness           -0.010803    -0.015551      0.151525  0.632503  1.000000
# speechiness         0.004288    -0.167422      0.259403  0.080999  0.002047
# acousticness        0.049778    -0.009620     -0.207240 -0.588686  0.014983
# instrumentalness    0.052461     0.087249     -0.048441 -0.009195 -0.005706
# liveness           -0.033469     0.010617     -0.136431  0.171041  0.020526
# valence            -0.100355    -0.138068      0.378336  0.388505 -0.004724
# tempo              -0.056942    -0.018837     -0.141259  0.188210  0.051729
#
#                   speechiness  acousticness  instrumentalness  liveness  \
# popularity           0.004288      0.049778          0.052461 -0.033469
# duration_ms         -0.167422     -0.009620          0.087249  0.010617
# danceability         0.259403     -0.207240         -0.048441 -0.136431
# energy               0.080999     -0.588686         -0.009195  0.171041
# loudness             0.002047      0.014983         -0.005706  0.020526
# speechiness          1.000000     -0.061643         -0.081172  0.035812
# acousticness        -0.061643      1.000000         -0.033373 -0.061747
# instrumentalness    -0.081172     -0.033373          1.000000 -0.031388
# liveness             0.035812     -0.061747         -0.031388  1.000000
# valence              0.075030     -0.184395         -0.086916  0.006194
# tempo                0.041354     -0.122968         -0.000357  0.008015
#
#                    valence     tempo
# popularity       -0.100355 -0.056942
# duration_ms      -0.138068 -0.018837
# danceability      0.378336 -0.141259
# energy            0.388505  0.188210
# loudness         -0.004724  0.051729
# speechiness       0.075030  0.041354
# acousticness     -0.184395 -0.122968
# instrumentalness -0.086916 -0.000357
# liveness          0.006194  0.008015
# valence           1.000000  0.118724
# tempo             0.118724  1.000000

# %%
import seaborn as sns

numeric_cols = ['popularity', 'duration_ms', 'danceability', 'energy', 'loudness',
                'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

corr = df[numeric_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0,
            square=True, linewidths=0.5, cbar_kws={'shrink': 0.8})
plt.title('Correlation Matrix', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# As can be seen, the highest correlation between the variables is between loudnes and energy (0.632503). This is somewhat understandable as the more loud the music is, the more it physically feels, and that may lead to being more energized.
#
# Lowest correlation is between acoustiness and energy (-0.588686). This is also somewhat explainable, as acoustic songs tend to be a bit slower and thus not so energized songs.

# %% [markdown]
# ## 5. Genre Analysis
# The following section examines differences between genres in terms of popularity and audio features.

# %%
plt.figure(figsize=(8, 4))
df['track_genre'].value_counts().plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Number of tracks by genre')
plt.xlabel('Genre')
plt.ylabel('Number')
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
df.boxplot(column='popularity', by='track_genre', rot=30)
plt.title('Popularity by genre')
plt.suptitle('')
plt.xlabel('Genre')
plt.ylabel('Popularity')
plt.tight_layout()
plt.show()

# %%
feature_cols = ['danceability', 'energy', 'speechiness',
                'acousticness', 'liveness', 'valence']

genre_means = df.groupby('track_genre')[feature_cols].mean()

plt.figure(figsize=(10, 6))
sns.heatmap(genre_means.T, annot=True, fmt='.2f', cmap='YlOrRd',
            linewidths=0.5, cbar_kws={'shrink': 0.8})
plt.title('Average audio feature values by genre')
plt.tight_layout()
plt.show()
